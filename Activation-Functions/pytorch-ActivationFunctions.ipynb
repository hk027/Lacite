# %%
# chapter1/activation_pytorch.py

import torch.nn as nn

# %%
# Sigmoid.
sigmoid = nn.Sigmoid()

# Tanh.
tanh = nn.Tanh()

# ReLU.
relu = nn.ReLU()

# LeakyReLU.
leaky_relu = nn.LeakyReLU(negative_slope=0.3)

# PReLU.
prelu = nn.PReLU(num_parameters=1, init=0.0)
# num_parameters représente le nombre de paramètres pour le gradient
# lorsque l'entrée est inférieure à 0, init représente la valeur
# d'initialisation.
