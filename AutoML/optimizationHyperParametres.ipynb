# %% [markdown]
# <h1>📊 Explication globale du code</h1>
#
# <p>
# Ce programme réalise un pipeline complet de <strong>AutoML</strong> avec
# <strong>H2O AutoML</strong>.
# </p>
#
# <h2>🔁 Étapes exécutées</h2>
#
# <h3>1. Initialisation</h3>
# <ul>
#   <li>Démarre H2O (moteur ML distribué)</li>
# </ul>
#
# <h3>2. Chargement des données</h3>
# <ul>
#   <li>Dataset Titanic (classification : survivant ou non)</li>
# </ul>
#
# <h3>3. Préparation des variables</h3>
# <ul>
#   <li><code>y</code> = variable cible (survived)</li>
#   <li><code>x</code> = variables explicatives</li>
# </ul>
#
# <h3>4. Split des données</h3>
# <ul>
#   <li>Entraînement (80%)</li>
#   <li>Test (20%)</li>
# </ul>
#
# <h3>5. AutoML</h3>
# <ul>
#   <li>Teste plusieurs modèles automatiquement</li>
#   <li>Optimise leurs hyperparamètres</li>
#   <li>Classe les modèles (leaderboard)</li>
# </ul>
#
# <h3>6. Sélection du meilleur modèle</h3>
# <ul>
#   <li><code>leader</code> = modèle le plus performant</li>
# </ul>
#
# <h3>7. Évaluation</h3>
# <ul>
#   <li>Calcul des performances sur le test set</li>
# </ul>
#
# <hr>
#
# <h2>🎯 Ce que fait AutoML</h2>
# <ul>
#   <li>Teste plusieurs algorithmes (Random Forest, GBM, XGBoost, Deep Learning)</li>
#   <li>Optimise automatiquement les hyperparamètres</li>
#   <li>Utilise la validation croisée</li>
#   <li>Classe les modèles par performance</li>
# </ul>
#
# <p><strong>Résultat :</strong> le meilleur modèle est sélectionné automatiquement.</p>

# %%
# Import de la bibliothèque principale H2O
import h2o

# Import du module AutoML de H2O pour automatiser le machine learning
from h2o.automl import H2OAutoML

# Démarrage du serveur H2O (local)
# Cela initialise l'environnement de calcul distribué
h2o.init()

# Chargement du dataset Titanic depuis une URL
# Les données sont automatiquement converties en H2OFrame (format H2O)
data = h2o.import_file("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv")

# Définition de la variable cible (ce qu'on veut prédire)
y = "survived"

# Récupération de toutes les colonnes du dataset
x = data.columns

# Suppression de la variable cible de la liste des variables explicatives
# (car on ne doit pas utiliser la réponse comme entrée)
x.remove(y)

# Division du dataset en deux parties :
# - 80% pour l'entraînement
# - 20% pour le test
train, test = data.split_frame(ratios=[0.8])

# Création d'un objet AutoML
# max_models=10 → limite le nombre de modèles entraînés
# seed=1 → permet de reproduire les résultats
aml = H2OAutoML(max_models=10, seed=1)

# Lancement de l'entraînement AutoML
# H2O va automatiquement :
# - tester plusieurs modèles (GBM, Random Forest, Deep Learning, etc.)
# - optimiser leurs hyperparamètres
# - sélectionner les meilleurs modèles
aml.train(x=x, y=y, training_frame=train)

# Récupération du meilleur modèle trouvé (leader du leaderboard)
leader = aml.leader

# Évaluation des performances du modèle sur les données de test
perf = leader.model_performance(test)

# Affichage des métriques de performance (accuracy, AUC, etc.)
print(perf)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         11 mins 37 secs
# H2O_cluster_timezone:       America/Toronto
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.10
# H2O_cluster_version_age:    1 month and 1 day
# H2O_cluster_name:           H2O_from_python_User_ht1rx5
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.897 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.9.25 final
# --------------------------  -----------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |█
# 15:34:03.502: AutoML: XGBoost is not available; skipping it.
# 15:34:03.648: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 15:34:04.673: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 15:34:11.449: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 15:34:12.225: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █
# 15:34:14.333: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 15:34:16.694: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ████
# 15:34:19.561: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 15:34:20.777: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 15:34:22.142: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ████
# 15:34:25.772: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 15:34:26.849: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ███████████████████████████████████████████████████| (done) 100%
# ModelMetricsRegressionGLM: glm
# ** Reported on test data. **
#
# MSE: 6.9749992878459046e-09
# RMSE: 8.351646117889517e-05
# MAE: 5.3607978384121736e-05
# RMSLE: 6.40281431277532e-05
# Mean Residual Deviance: 6.9749992878459046e-09
# R^2: 0.9999999712829702
# Null degrees of freedom: 165
# Residual degrees of freedom: 133
# Null deviance: 40.5732014268728
# Residual deviance: 1.1578498817824202e-06
# AIC: -2578.547386458478
