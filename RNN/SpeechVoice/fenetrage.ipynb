# %%
import numpy as np
from scipy.io import wavfile

# %%
rate, data = wavfile.read('harvard.wav')  # signal audio
frame_size = 0.025  # 25 ms
frame_length = int(rate * frame_size)
print(f"Nombre d'échantillons par fenêtre : {frame_length}")
# Out:
# Nombre d'échantillons par fenêtre : 1102
# C:\Users\User\AppData\Local\Temp\ipykernel_17168\393180984.py:1: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   rate, data = wavfile.read('harvard.wav')  # signal audio
