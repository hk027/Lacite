# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 400  # taille de la frame (25 ms à 16 kHz)
hamming_window = np.hamming(N)

plt.plot(hamming_window)
plt.title("Fenêtre de Hamming")
plt.xlabel("Échantillons")
plt.ylabel("Amplitude")
plt.show()
